# %%
# The data set
import pandas as pd
df = pd.read_excel(r"C:\Users\joerl\Downloads\excel.xlsx")

pd.set_option('display.max_rows', None)       # Show all rows
pd.set_option('display.max_columns', None)    # Show all columns
pd.set_option('display.width', None)          # Don't truncate wide output
pd.set_option('display.max_colwidth', None)   # Show full column content

df
# Out:
#           Retailer  Retailer ID     Region Gender Type   Product Category  \
# 0           Amazon      1185732    Midwest         Men            Apparel
# 1           Amazon      1185732    Midwest         Men    Street Footwear
# 2           Amazon      1185732    Midwest         Men  Athletic Footwear
# 3           Amazon      1185732    Midwest         Men            Apparel
# 4           Amazon      1185732    Midwest         Men    Street Footwear
# 5           Amazon      1185732    Midwest         Men  Athletic Footwear
# 6           Amazon      1185732    Midwest         Men            Apparel
# 7           Amazon      1185732    Midwest         Men    Street Footwear
# 8           Amazon      1185732    Midwest         Men  Athletic Footwear
# 9           Amazon      1185732    Midwest         Men            Apparel
# 10          Amazon      1185732    Midwest         Men    Street Footwear
# 11          Amazon      1185732    Midwest         Men  Athletic Footwear
# 12          Amazon      1185732    Midwest         Men            Apparel
# 13          Amazon      1185732    Midwest         Men    Street Footwear
# 14          Amazon      1185732    Midwest         Men  Athletic Footwear
# 15          Amazon      1185732    Midwest         Men            Apparel
# 16          Amazon      1185732    Midwest         Men    Street Footwear
# 17          Amazon      1185732    Midwest         Men  Athletic Footwear
# 18          Amazon      1185732    Midwest         Men            Apparel
# 19          Amazon      1185732    Midwest         Men    Street Footwear
# 20          Amazon      1185732    Midwest         Men  Athletic Footwear
# 21          Amazon      1185732    Midwest         Men            Apparel
# 22          Amazon      1185732    Midwest         Men    Street Footwear
# 23          Amazon      1185732    Midwest         Men  Athletic Footwear
# 24          Amazon      1185732    Midwest         Men            Apparel
# 25          Amazon      1185732    Midwest       Women  Athletic Footwear
# 26          Amazon      1185732    Midwest       Women            Apparel
# 27          Amazon      1185732    Midwest       Women    Street Footwear
# 28          Amazon      1185732    Midwest       Women  Athletic Footwear
# 29          Amazon      1185732    Midwest       Women            Apparel
# 30          Amazon      1185732    Midwest       Women    Street Footwear
# 31          Amazon      1185732    Midwest       Women  Athletic Footwear
# 32          Amazon      1185732    Midwest       Women            Apparel
# 33          Amazon      1185732    Midwest       Women    Street Footwear
# 34          Amazon      1185732    Midwest       Women  Athletic Footwear
# 35          Amazon      1185732    Midwest       Women            Apparel
# 36          Amazon      1185732    Midwest       Women    Street Footwear
# 37          Amazon      1185732    Midwest       Women  Athletic Footwear
# 38          Amazon      1185732    Midwest       Women            Apparel
# 39          Amazon      1185732    Midwest       Women    Street Footwear
# 40          Amazon      1185732    Midwest       Women  Athletic Footwear
# 41          Amazon      1185732    Midwest       Women            Apparel
# 42          Amazon      1185732    Midwest       Women    Street Footwear
# 43          Amazon      1185732    Midwest       Women  Athletic Footwear
# 44          Amazon      1185732    Midwest       Women            Apparel
# 45          Amazon      1185732    Midwest       Women    Street Footwear
# 46          Amazon      1185732    Midwest       Women  Athletic Footwear
# 47          Amazon      1185732    Midwest       Women            Apparel
# 48          Amazon      1185732    Midwest       Women    Street Footwear
# 49          Amazon      1185732    Midwest       Women  Athletic Footwear
# 50          Amazon      1185732    Midwest       Women            Apparel
# 51     Foot Locker      1185732  Northeast         Men            Apparel
# 52     Foot Locker      1185732  Northeast         Men    Street Footwear
# 53     Foot Locker      1185732  Northeast         Men  Athletic Footwear
# 54     Foot Locker      1185732  Northeast         Men            Apparel
# 55     Foot Locker      1185732  Northeast         Men    Street Footwear
# 56     Foot Locker      1185732  Northeast         Men  Athletic Footwear
# 57     Foot Locker      1185732  Northeast         Men            Apparel
# 58     Foot Locker      1185732  Northeast         Men    Street Footwear
# 59     Foot Locker      1185732  Northeast         Men  Athletic Footwear
# 60     Foot Locker      1185732  Northeast         Men            Apparel
# 61     Foot Locker      1185732  Northeast         Men    Street Footwear
# 62     Foot Locker      1185732  Northeast         Men  Athletic Footwear
# 63     Foot Locker      1185732  Northeast         Men            Apparel
# 64     Foot Locker      1185732  Northeast         Men    Street Footwear
# 65     Foot Locker      1185732  Northeast         Men  Athletic Footwear
# 66     Foot Locker      1185732  Northeast         Men            Apparel
# 67     Foot Locker      1185732  Northeast         Men    Street Footwear
# 68     Foot Locker      1185732  Northeast         Men  Athletic Footwear
# 69     Foot Locker      1185732  Northeast         Men            Apparel
# 70     Foot Locker      1185732  Northeast         Men    Street Footwear
# 71     Foot Locker      1185732  Northeast         Men  Athletic Footwear
# 72     Foot Locker      1185732  Northeast         Men            Apparel
# 73     Foot Locker      1185732  Northeast         Men    Street Footwear
# 74     Foot Locker      1185732  Northeast         Men  Athletic Footwear
# 75     Foot Locker      1185732  Northeast         Men            Apparel
# 76     Foot Locker      1185732  Northeast       Women            Apparel
# 77     Foot Locker      1185732  Northeast       Women    Street Footwear
# 78     Foot Locker      1185732  Northeast       Women  Athletic Footwear
# 79     Foot Locker      1185732  Northeast       Women            Apparel
# 80     Foot Locker      1185732  Northeast       Women    Street Footwear
# 81     Foot Locker      1185732  Northeast       Women  Athletic Footwear
# 82     Foot Locker      1185732  Northeast       Women            Apparel
# 83     Foot Locker      1185732  Northeast       Women    Street Footwear
# 84     Foot Locker      1185732  Northeast       Women  Athletic Footwear
# 85     Foot Locker      1185732  Northeast       Women            Apparel
# 86     Foot Locker      1185732  Northeast       Women    Street Footwear
# 87     Foot Locker      1185732  Northeast       Women  Athletic Footwear
# 88     Foot Locker      1185732  Northeast       Women            Apparel
# 89     Foot Locker      1185732  Northeast       Women    Street Footwear
# 90     Foot Locker      1185732  Northeast       Women  Athletic Footwear
# 91     Foot Locker      1185732  Northeast       Women            Apparel
# 92     Foot Locker      1185732  Northeast       Women    Street Footwear
# 93     Foot Locker      1185732  Northeast       Women  Athletic Footwear
# 94     Foot Locker      1185732  Northeast       Women            Apparel
# 95     Foot Locker      1185732  Northeast       Women    Street Footwear
# 96     Foot Locker      1185732  Northeast       Women  Athletic Footwear
# 97     Foot Locker      1185732  Northeast       Women            Apparel
# 98     Foot Locker      1185732  Northeast       Women    Street Footwear
# 99     Foot Locker      1185732  Northeast       Women  Athletic Footwear
# 100  Sports Direct      1185732      South         Men            Apparel
# 101  Sports Direct      1185732      South         Men    Street Footwear
# 102  Sports Direct      1185732      South         Men  Athletic Footwear
# 103  Sports Direct      1185732      South         Men            Apparel
# 104  Sports Direct      1185732      South         Men    Street Footwear
# 105  Sports Direct      1185732      South         Men  Athletic Footwear
# 106  Sports Direct      1185732      South         Men            Apparel
# 107        Walmart      1185732      South         Men  Athletic Footwear
# 108        Walmart      1185732      South         Men            Apparel
# 109        Walmart      1185732      South         Men    Street Footwear
# 110        Walmart      1185732      South         Men  Athletic Footwear
# 111        Walmart      1185732      South         Men            Apparel
# 112        Walmart      1185732      South         Men    Street Footwear
# 113        Walmart      1185732      South         Men  Athletic Footwear
# 114        Walmart      1185732      South         Men            Apparel
# 115        Walmart      1185732      South         Men    Street Footwear
# 116        Walmart      1185732      South         Men  Athletic Footwear
# 117        Walmart      1185732      South         Men            Apparel
# 118        Walmart      1185732      South         Men  Athletic Footwear
# 119        Walmart      1185732      South         Men            Apparel
# 120        Walmart      1185732      South         Men    Street Footwear
# 121        Walmart      1185732      South         Men  Athletic Footwear
# 122        Walmart      1185732      South         Men            Apparel
# 123        Walmart      1185732      South         Men    Street Footwear
# 124  Sports Direct      1185732      South       Women    Street Footwear
# 125  Sports Direct      1185732      South       Women  Athletic Footwear
# 126  Sports Direct      1185732      South       Women            Apparel
# 127  Sports Direct      1185732      South       Women            Apparel
# 128  Sports Direct      1185732      South       Women    Street Footwear
# 129  Sports Direct      1185732      South       Women  Athletic Footwear
# 130  Sports Direct      1185732      South       Women            Apparel
# 131  Sports Direct      1185732      South       Women    Street Footwear
# 132  Sports Direct      1185732      South       Women  Athletic Footwear
# 133  Sports Direct      1185732      South       Women            Apparel
# 134        Walmart      1185732      South       Women    Street Footwear
# 135        Walmart      1185732      South       Women  Athletic Footwear
# 136        Walmart      1185732      South       Women            Apparel
# 137        Walmart      1185732      South       Women    Street Footwear
# 138        Walmart      1185732      South       Women  Athletic Footwear
# 139        Walmart      1185732      South       Women            Apparel
# 140        Walmart      1185732      South       Women    Street Footwear
# 141        Walmart      1185732      South       Women  Athletic Footwear
# 142        Walmart      1185732      South       Women            Apparel
# 143        Walmart      1185732      South       Women    Street Footwear
# 144        Walmart      1185732      South       Women  Athletic Footwear
# 145        Walmart      1185732      South       Women    Street Footwear
# 146        Walmart      1185732      South       Women  Athletic Footwear
# 147        Walmart      1185732      South       Women            Apparel
# 148        Walmart      1185732      South       Women    Street Footwear
# 149        Walmart      1185732      South       Women  Athletic Footwear
# 150        Walmart      1185732      South       Women            Apparel
# 151  Sports Direct      1185732  Southeast         Men    Street Footwear
# 152  Sports Direct      1185732  Southeast         Men  Athletic Footwear
# 153  Sports Direct      1185732  Southeast         Men            Apparel
# 154  Sports Direct      1185732  Southeast         Men    Street Footwear
# 155  Sports Direct      1185732  Southeast         Men  Athletic Footwear
# 156  Sports Direct      1185732  Southeast         Men    Street Footwear
# 157  Sports Direct      1185732  Southeast         Men  Athletic Footwear
# 158  Sports Direct      1185732  Southeast         Men            Apparel
# 159  Sports Direct      1185732  Southeast         Men    Street Footwear
# 160  Sports Direct      1185732  Southeast         Men  Athletic Footwear
# 161    Foot Locker      1185732  Southeast         Men    Street Footwear
# 162    Foot Locker      1185732  Southeast         Men  Athletic Footwear
# 163    Foot Locker      1185732  Southeast         Men            Apparel
# 164    Foot Locker      1185732  Southeast         Men    Street Footwear
# 165    Foot Locker      1185732  Southeast         Men  Athletic Footwear
# 166      West Gear      1185732  Southeast         Men    Street Footwear
# 167      West Gear      1185732  Southeast         Men  Athletic Footwear
# 168      West Gear      1185732  Southeast         Men            Apparel
# 169      West Gear      1185732  Southeast         Men    Street Footwear
# 170      West Gear      1185732  Southeast         Men  Athletic Footwear
# 171      West Gear      1185732  Southeast         Men    Street Footwear
# 172      West Gear      1185732  Southeast         Men  Athletic Footwear
# 173      West Gear      1185732  Southeast         Men            Apparel
# 174      West Gear      1185732  Southeast         Men    Street Footwear
# 175      West Gear      1185732  Southeast         Men  Athletic Footwear
# 176    Foot Locker      1185732  Southeast         Men            Apparel
# 177    Foot Locker      1185732  Southeast         Men    Street Footwear
# 178    Foot Locker      1185732  Southeast         Men  Athletic Footwear
# 179  Sports Direct      1185732  Southeast       Women    Street Footwear
# 180  Sports Direct      1185732  Southeast       Women  Athletic Footwear
# 181  Sports Direct      1185732  Southeast       Women            Apparel
# 182  Sports Direct      1185732  Southeast       Women    Street Footwear
# 183  Sports Direct      1185732  Southeast       Women    Street Footwear
# 184  Sports Direct      1185732  Southeast       Women  Athletic Footwear
# 185  Sports Direct      1185732  Southeast       Women            Apparel
# 186  Sports Direct      1185732  Southeast       Women    Street Footwear
# 187    Foot Locker      1185732  Southeast       Women    Street Footwear
# 188    Foot Locker      1185732  Southeast       Women  Athletic Footwear
# 189    Foot Locker      1185732  Southeast       Women            Apparel
# 190    Foot Locker      1185732  Southeast       Women    Street Footwear
# 191      West Gear      1185732  Southeast       Women    Street Footwear
# 192      West Gear      1185732  Southeast       Women  Athletic Footwear
# 193      West Gear      1185732  Southeast       Women            Apparel
# 194      West Gear      1185732  Southeast       Women    Street Footwear
# 195      West Gear      1185732  Southeast       Women    Street Footwear
# 196      West Gear      1185732  Southeast       Women  Athletic Footwear
# 197      West Gear      1185732  Southeast       Women            Apparel
# 198      West Gear      1185732  Southeast       Women    Street Footwear
# 199    Foot Locker      1185732  Southeast       Women            Apparel
# 200    Foot Locker      1185732  Southeast       Women    Street Footwear
# 201      West Gear      1185732  Southeast       Women  Athletic Footwear
# 202      West Gear      1185732       West         Men  Athletic Footwear
# 203      West Gear      1185732       West         Men            Apparel
# 204      West Gear      1185732       West         Men    Street Footwear
# 205      West Gear      1185732       West         Men  Athletic Footwear
# 206      West Gear      1185732       West         Men            Apparel
# 207      West Gear      1185732       West         Men    Street Footwear
# 208      West Gear      1185732       West         Men  Athletic Footwear
# 209      West Gear      1185732       West         Men            Apparel
# 210      West Gear      1185732       West         Men    Street Footwear
# 211      West Gear      1185732       West         Men  Athletic Footwear
# 212      West Gear      1185732       West         Men            Apparel
# 213      West Gear      1185732       West         Men            Apparel
# 214      West Gear      1185732       West         Men    Street Footwear
# 215      West Gear      1185732       West         Men  Athletic Footwear
# 216      West Gear      1185732       West         Men            Apparel
# 217      West Gear      1185732       West         Men    Street Footwear
# 218      West Gear      1185732       West         Men  Athletic Footwear
# 219      West Gear      1185732       West         Men            Apparel
# 220      West Gear      1185732       West         Men    Street Footwear
# 221      West Gear      1185732       West         Men  Athletic Footwear
# 222      West Gear      1185732       West         Men            Apparel
# 223      West Gear      1185732       West         Men    Street Footwear
# 224      West Gear      1185732       West         Men  Athletic Footwear
# 225      West Gear      1185732       West         Men            Apparel
# 226      West Gear      1185732       West         Men    Street Footwear
# 227      West Gear      1185732       West       Women    Street Footwear
# 228      West Gear      1185732       West       Women  Athletic Footwear
# 229      West Gear      1185732       West       Women            Apparel
# 230      West Gear      1185732       West       Women    Street Footwear
# 231      West Gear      1185732       West       Women  Athletic Footwear
# 232      West Gear      1185732       West       Women            Apparel
# 233      West Gear      1185732       West       Women    Street Footwear
# 234      West Gear      1185732       West       Women  Athletic Footwear
# 235      West Gear      1185732       West       Women            Apparel
# 236      West Gear      1185732       West       Women    Street Footwear
# 237      West Gear      1185732       West       Women  Athletic Footwear
# 238      West Gear      1185732       West       Women            Apparel
# 239      West Gear      1185732       West       Women  Athletic Footwear
# 240      West Gear      1185732       West       Women            Apparel
# 241      West Gear      1185732       West       Women    Street Footwear
# 242      West Gear      1185732       West       Women  Athletic Footwear
# 243      West Gear      1185732       West       Women            Apparel
# 244      West Gear      1185732       West       Women    Street Footwear
# 245      West Gear      1185732       West       Women  Athletic Footwear
# 246      West Gear      1185732       West       Women            Apparel
# 247      West Gear      1185732       West       Women    Street Footwear
# 248      West Gear      1185732       West       Women  Athletic Footwear
# 249      West Gear      1185732       West       Women            Apparel
# 250      West Gear      1185732       West       Women    Street Footwear
# 251      West Gear      1185732       West       Women  Athletic Footwear
# 252      West Gear      1185732       West       Women            Apparel
#
#      Price per Unit  Units Sold  Total Sales  Operating Profit  \
# 0                45         450       202500          70875.00
# 1                30         770       231000          92400.00
# 2                30         450       135000          47250.00
# 3                40         375       150000          52500.00
# 4                30         725       217500          87000.00
# 5                30         425       127500          44625.00
# 6                45         375       168750          59062.50
# 7                45         795       357750         143100.00
# 8                45         500       225000          78750.00
# 9                50         450       225000          78750.00
# 10               50         800       400000         160000.00
# 11               45         550       247500          86625.00
# 12               65         500       325000         113750.00
# 13               65         900       585000         234000.00
# 14               60         650       390000         136500.00
# 15               65         550       357500         125125.00
# 16               65         875       568750         227500.00
# 17               60         650       390000         136500.00
# 18               55         500       275000          96250.00
# 19               55         775       426250         170500.00
# 20               50         575       287500         100625.00
# 21               35         450       157500          55125.00
# 22               40         725       290000         116000.00
# 23               30         550       165000          57750.00
# 24               40         400       160000          56000.00
# 25               30         375       112500          45000.00
# 26               30         550       165000          82500.00
# 27               20         475        95000          38000.00
# 28               25         325        81250          32500.00
# 29               30         475       142500          71250.00
# 30               20         425        85000          34000.00
# 31               25         350        87500          35000.00
# 32               35         525       183750          91875.00
# 33               40         475       190000          76000.00
# 34               40         425       170000          68000.00
# 35               55         550       302500         151250.00
# 36               50         525       262500         105000.00
# 37               50         500       250000         100000.00
# 38               70         675       472500         236250.00
# 39               55         575       316250         126500.00
# 40               55         525       288750         115500.00
# 41               70         725       507500         253750.00
# 42               55         575       316250         126500.00
# 43               45         525       236250          94500.00
# 44               60         675       405000         202500.00
# 45               25         475       118750          47500.00
# 46               25         450       112500          45000.00
# 47               40         550       220000         110000.00
# 48               30         425       127500          51000.00
# 49               30         400       120000          48000.00
# 50               40         525       210000         105000.00
# 51               55         125        68750          24062.50
# 52               45         475       213750         117562.50
# 53               45         125        56250          19687.50
# 54               55         125        68750          24062.50
# 55               50         445       222500         122375.00
# 56               50         150        75000          26250.00
# 57               60          75        45000          13500.00
# 58               50         450       225000         112500.00
# 59               50         150        75000          22500.00
# 60               60          75        45000          13500.00
# 61               60         470       282000         141000.00
# 62               60         175       105000          31500.00
# 63               65         125        81250          24375.00
# 64               65         500       325000         178750.00
# 65               60         250       150000          52500.00
# 66               65         150        97500          34125.00
# 67               65         500       325000         178750.00
# 68               60         300       180000          63000.00
# 69               65         200       130000          45500.00
# 70               65         525       341250         187687.50
# 71               60         300       180000          63000.00
# 72               65         175       113750          39812.50
# 73               65         475       308750         154375.00
# 74               50         275       137500          41250.00
# 75               55         125        68750          20625.00
# 76               45         225       101250          30375.00
# 77               35         175        61250          24500.00
# 78               40          50        20000           8000.00
# 79               45         225       101250          30375.00
# 80               40         175        70000          28000.00
# 81               45          25        11250           4500.00
# 82               50         175        87500          21875.00
# 83               40         150        60000          21000.00
# 84               45          75        33750          11812.50
# 85               50         200       100000          25000.00
# 86               55         150        82500          28875.00
# 87               55         100        55000          19250.00
# 88               70         250       175000          52500.00
# 89               55         175        96250          38500.00
# 90               55         150        82500          33000.00
# 91               70         300       210000          63000.00
# 92               55         225       123750          49500.00
# 93               55         175        96250          38500.00
# 94               70         375       262500          78750.00
# 95               55         225       123750          49500.00
# 96               55         200       110000          44000.00
# 97               70         350       245000          73500.00
# 98               45         200        90000          31500.00
# 99               45         175        78750          27562.50
# 100              65         124         8060           4030.00
# 101              22         206         4532           1994.08
# 102              15         153         2295            872.10
# 103              59         132         7788           3115.20
# 104              48         256        12288           5775.36
# 105              44         201         8844           3272.28
# 106              54         157         8478           3221.64
# 107              55         600       330000         115500.00
# 108              60         500       300000         105000.00
# 109              60         825       495000         198000.00
# 110              55         600       330000         115500.00
# 111              50         450       225000          78750.00
# 112              50         725       362500         145000.00
# 113              45         525       236250          82687.50
# 114              30         400       120000          42000.00
# 115              35         675       236250          94500.00
# 116              25         500       125000          43750.00
# 117              35         350       122500          42875.00
# 118              53         156         8268           3720.60
# 119              59         150         8850           4248.00
# 120              56         215        12040           6501.60
# 121              50         168         8400           4032.00
# 122              46         122         5612           2525.40
# 123              47         203         9541           5152.14
# 124              59         137         8083           4364.82
# 125              56         133         7448           3872.96
# 126              71         144        10224           6236.64
# 127              27         162         4374           2361.96
# 128              22         119         2618           1099.56
# 129              43         153         6579           2894.76
# 130              51         168         8568           4883.76
# 131              43         158         6794           3057.30
# 132              41         143         5863           2755.61
# 133              53         178         9434           5188.70
# 134              50         525       262500         105000.00
# 135              50         475       237500          95000.00
# 136              65         675       438750         219375.00
# 137              50         525       262500         105000.00
# 138              40         475       190000          76000.00
# 139              55         625       343750         171875.00
# 140              20         425        85000          34000.00
# 141              20         400        80000          32000.00
# 142              35         500       175000          87500.00
# 143              25         375        93750          37500.00
# 144              25         350        87500          35000.00
# 145              48         142         6816           3408.00
# 146              48         124         5952           3154.56
# 147              61         176        10736           6548.96
# 148              48         147         7056           3669.12
# 149              39         128         4992           2595.84
# 150              53         169         8957           5822.05
# 151              35         750       262500         131250.00
# 152              35         550       192500          77000.00
# 153              45         450       202500          81000.00
# 154              35         800       280000         140000.00
# 155              35         450       157500          63000.00
# 156              23         233         5359           2786.68
# 157              28         187         5236           2460.92
# 158              30         140         4200           1890.00
# 159              26         256         6656           3660.80
# 160              27         153         4131           1858.95
# 161              26         349         9074           4264.78
# 162              30         256         7680           3072.00
# 163              35         247         8645           3371.55
# 164              31         376        11656           5594.88
# 165              27         247         6669           2534.22
# 166              45         850       382500         172125.00
# 167              45         650       292500         102375.00
# 168              55         550       302500         105875.00
# 169              45         900       405000         182250.00
# 170              45         550       247500          86625.00
# 171              30         272         8160           4161.60
# 172              36         221         7956           3182.40
# 173              36         193         6948           2848.68
# 174              36         288        10368           4872.96
# 175              31         165         5115           2097.15
# 176              55         750       412500         144375.00
# 177              45        1100       495000         222750.00
# 178              45         750       337500         118125.00
# 179              25         550       137500          41250.00
# 180              30         400       120000          42000.00
# 181              35         550       192500         105875.00
# 182              25         500       125000          37500.00
# 183              18         176         3168           1013.76
# 184              21         136         2856           1199.52
# 185              25         193         4825           2798.50
# 186              17         170         2890           1040.40
# 187              24         264         6336           2027.52
# 188              25         209         5225           1828.75
# 189              30         281         8430           4467.90
# 190              21         248         5208           1562.40
# 191              35         650       227500          56875.00
# 192              40         500       200000          60000.00
# 193              45         650       292500         146250.00
# 194              35         600       210000          52500.00
# 195              26         202         5252           1523.08
# 196              30         170         5100           1887.00
# 197              35         221         7735           4254.25
# 198              23         204         4692           1501.44
# 199              45         850       382500         191250.00
# 200              35         800       280000          70000.00
# 201              40         675       270000          81000.00
# 202              25         450       112500          39375.00
# 203              20         325        65000          22750.00
# 204              30         575       172500          69000.00
# 205              20         400        80000          28000.00
# 206              30         275        82500          28875.00
# 207              30         550       165000          66000.00
# 208              20         400        80000          28000.00
# 209              40         350       140000          49000.00
# 210              40         700       280000         112000.00
# 211              30         500       150000          52500.00
# 212              40         400       160000          56000.00
# 213              32         101         3232           1454.40
# 214              29         168         4872           2533.44
# 215              28         102         2856           1428.00
# 216              38          75         2850           1425.00
# 217              27         181         4887           2443.50
# 218              25          94         2350           1057.50
# 219              33          74         2442           1123.32
# 220              32         174         5568           2839.68
# 221              29         101         2929           1435.21
# 222              39          75         2925           1462.50
# 223              28         182         5096           2598.96
# 224              24         112         2688           1317.12
# 225              34         108         3672           1652.40
# 226              34         224         7616           3960.32
# 227              10         350        35000          12250.00
# 228              10         325        32500          13000.00
# 229              25         400       100000          50000.00
# 230              20         300        60000          21000.00
# 231              20         275        55000          22000.00
# 232              35         400       140000          70000.00
# 233              20         345        69000          24150.00
# 234              20         375        75000          30000.00
# 235              45         450       202500         101250.00
# 236              30         450       135000          47250.00
# 237              30         400       120000          48000.00
# 238              45         500       225000         112500.00
# 239              19          87         1653            826.50
# 240              24         131         3144           1949.28
# 241              18         112         2016           1008.00
# 242              23          73         1679            889.87
# 243              29         100         2900           1856.00
# 244              14          98         1372            631.12
# 245              18          70         1260            667.80
# 246              24         112         2688           1612.80
# 247              25          98         2450           1225.00
# 248              23          72         1656            910.80
# 249              44         120         5280           3432.00
# 250              19         115         2185           1070.65
# 251              19         108         2052           1046.52
# 252              38         150         5700           3420.00
#
#      Operating Margin Sales Method
# 0                0.35       Online
# 1                0.40       Online
# 2                0.35       Online
# 3                0.35       Online
# 4                0.40       Online
# 5                0.35       Online
# 6                0.35       Online
# 7                0.40       Online
# 8                0.35       Online
# 9                0.35       Online
# 10               0.40       Online
# 11               0.35       Online
# 12               0.35       Online
# 13               0.40       Online
# 14               0.35       Online
# 15               0.35       Online
# 16               0.40       Online
# 17               0.35       Online
# 18               0.35       Online
# 19               0.40       Online
# 20               0.35       Online
# 21               0.35       Online
# 22               0.40       Online
# 23               0.35       Online
# 24               0.35       Online
# 25               0.40       Online
# 26               0.50       Online
# 27               0.40       Online
# 28               0.40       Online
# 29               0.50       Online
# 30               0.40       Online
# 31               0.40       Online
# 32               0.50       Online
# 33               0.40       Online
# 34               0.40       Online
# 35               0.50       Online
# 36               0.40       Online
# 37               0.40       Online
# 38               0.50       Online
# 39               0.40       Online
# 40               0.40       Online
# 41               0.50       Online
# 42               0.40       Online
# 43               0.40       Online
# 44               0.50       Online
# 45               0.40       Online
# 46               0.40       Online
# 47               0.50       Online
# 48               0.40       Online
# 49               0.40       Online
# 50               0.50       Online
# 51               0.35       Outlet
# 52               0.55       Outlet
# 53               0.35       Outlet
# 54               0.35       Outlet
# 55               0.55       Outlet
# 56               0.35       Outlet
# 57               0.30       Outlet
# 58               0.50       Outlet
# 59               0.30       Outlet
# 60               0.30       Outlet
# 61               0.50       Outlet
# 62               0.30       Outlet
# 63               0.30       Outlet
# 64               0.55       Outlet
# 65               0.35       Outlet
# 66               0.35       Outlet
# 67               0.55       Outlet
# 68               0.35       Outlet
# 69               0.35       Outlet
# 70               0.55       Outlet
# 71               0.35       Outlet
# 72               0.35       Outlet
# 73               0.50       Outlet
# 74               0.30       Outlet
# 75               0.30       Outlet
# 76               0.30       Outlet
# 77               0.40       Outlet
# 78               0.40       Outlet
# 79               0.30       Outlet
# 80               0.40       Outlet
# 81               0.40       Outlet
# 82               0.25       Outlet
# 83               0.35       Outlet
# 84               0.35       Outlet
# 85               0.25       Outlet
# 86               0.35       Outlet
# 87               0.35       Outlet
# 88               0.30       Outlet
# 89               0.40       Outlet
# 90               0.40       Outlet
# 91               0.30       Outlet
# 92               0.40       Outlet
# 93               0.40       Outlet
# 94               0.30       Outlet
# 95               0.40       Outlet
# 96               0.40       Outlet
# 97               0.30       Outlet
# 98               0.35       Outlet
# 99               0.35       Outlet
# 100              0.50       Online
# 101              0.44       Outlet
# 102              0.38       Outlet
# 103              0.40       Outlet
# 104              0.47       Outlet
# 105              0.37       Outlet
# 106              0.38       Outlet
# 107              0.35       Online
# 108              0.35       Online
# 109              0.40       Online
# 110              0.35       Online
# 111              0.35       Online
# 112              0.40       Online
# 113              0.35       Online
# 114              0.35       Online
# 115              0.40       Online
# 116              0.35       Online
# 117              0.35       Online
# 118              0.45       Online
# 119              0.48       Online
# 120              0.54       Online
# 121              0.48       Online
# 122              0.45       Online
# 123              0.54       Online
# 124              0.54       Online
# 125              0.52       Online
# 126              0.61       Online
# 127              0.54       Outlet
# 128              0.42       Outlet
# 129              0.44       Outlet
# 130              0.57       Outlet
# 131              0.45       Outlet
# 132              0.47       Outlet
# 133              0.55       Outlet
# 134              0.40       Online
# 135              0.40       Online
# 136              0.50       Online
# 137              0.40       Online
# 138              0.40       Online
# 139              0.50       Online
# 140              0.40       Online
# 141              0.40       Online
# 142              0.50       Online
# 143              0.40       Online
# 144              0.40       Online
# 145              0.50       Online
# 146              0.53       Online
# 147              0.61       Online
# 148              0.52       Online
# 149              0.52       Online
# 150              0.65       Online
# 151              0.50     In-store
# 152              0.40     In-store
# 153              0.40     In-store
# 154              0.50     In-store
# 155              0.40     In-store
# 156              0.52       Outlet
# 157              0.47       Outlet
# 158              0.45       Outlet
# 159              0.55       Outlet
# 160              0.45       Outlet
# 161              0.47       Outlet
# 162              0.40       Outlet
# 163              0.39       Outlet
# 164              0.48       Outlet
# 165              0.38       Outlet
# 166              0.45     In-store
# 167              0.35     In-store
# 168              0.35     In-store
# 169              0.45     In-store
# 170              0.35     In-store
# 171              0.51       Outlet
# 172              0.40       Outlet
# 173              0.41       Outlet
# 174              0.47       Outlet
# 175              0.41       Outlet
# 176              0.35     In-store
# 177              0.45     In-store
# 178              0.35     In-store
# 179              0.30     In-store
# 180              0.35     In-store
# 181              0.55     In-store
# 182              0.30     In-store
# 183              0.32       Outlet
# 184              0.42       Outlet
# 185              0.58       Outlet
# 186              0.36       Outlet
# 187              0.32       Outlet
# 188              0.35       Outlet
# 189              0.53       Outlet
# 190              0.30       Outlet
# 191              0.25     In-store
# 192              0.30     In-store
# 193              0.50     In-store
# 194              0.25     In-store
# 195              0.29       Outlet
# 196              0.37       Outlet
# 197              0.55       Outlet
# 198              0.32       Outlet
# 199              0.50     In-store
# 200              0.25     In-store
# 201              0.30     In-store
# 202              0.35     In-store
# 203              0.35     In-store
# 204              0.40     In-store
# 205              0.35     In-store
# 206              0.35     In-store
# 207              0.40     In-store
# 208              0.35     In-store
# 209              0.35     In-store
# 210              0.40     In-store
# 211              0.35     In-store
# 212              0.35     In-store
# 213              0.45       Online
# 214              0.52       Online
# 215              0.50       Online
# 216              0.50       Online
# 217              0.50       Online
# 218              0.45       Online
# 219              0.46       Online
# 220              0.51       Online
# 221              0.49       Online
# 222              0.50       Online
# 223              0.51       Online
# 224              0.49       Online
# 225              0.45       Online
# 226              0.52       Online
# 227              0.35     In-store
# 228              0.40     In-store
# 229              0.50     In-store
# 230              0.35     In-store
# 231              0.40     In-store
# 232              0.50     In-store
# 233              0.35     In-store
# 234              0.40     In-store
# 235              0.50     In-store
# 236              0.35     In-store
# 237              0.40     In-store
# 238              0.50     In-store
# 239              0.50       Online
# 240              0.62       Online
# 241              0.50       Online
# 242              0.53       Online
# 243              0.64       Online
# 244              0.46       Online
# 245              0.53       Online
# 246              0.60       Online
# 247              0.50       Online
# 248              0.55       Online
# 249              0.65       Online
# 250              0.49       Online
# 251              0.51       Online
# 252              0.60       Online

# %%
# Proof of clean data

# Removing any rows with missing values
df_cleaned = df.dropna()

# Checking for null values
null_check = df_cleaned.isnull().sum()

# Showing the number of rows after cleaning
row_count = df_cleaned.shape[0]

# Results
print("Null values in each column after cleaning:")
print(null_check)

print(f"\nTotal number of rows after cleaning: {row_count}")

# Proof condition
if row_count >= 100 and null_check.sum() == 0:
    print(" Data is clean and contains at least 100 rows.")
else:
    print(" Data is not clean or has fewer than 100 rows.")
# Out:
# Null values in each column after cleaning:
# Retailer            0
# Retailer ID         0
# Region              0
# Gender Type         0
# Product Category    0
# Price per Unit      0
# Units Sold          0
# Total Sales         0
# Operating Profit    0
# Operating Margin    0
# Sales Method        0
# dtype: int64
#
# Total number of rows after cleaning: 253
#  Data is clean and contains at least 100 rows.

# %%
import numpy as np

prices = df['Price per Unit'].values
units_sold = df['Units Sold'].values
sales = df['Total Sales'].values
profits = df['Operating Profit'].values

# %%
# Operations Using Numpy
# 1. Mean of Prices
mean_price = np.mean(prices)
print(f"1️ Mean Price per Unit: {mean_price:.2f}")

# 2. Median of Units Sold
median_units = np.median(units_sold)
print(f"2️ Median Units Sold: {median_units}")

# 3. Standard Deviation of Total Sales
std_sales = np.std(sales)
print(f"3️ Standard Deviation of Total Sales: {std_sales:.2f}")

# 4. Maximum Profit
max_profit = np.max(profits)
print(f"4️ Maximum Operating Profit: {max_profit:.2f}")

# 5. Minimum Profit
min_profit = np.min(profits)
print(f"5️ Minimum Operating Profit: {min_profit:.2f}")

# 6. Total revenue (sum of Total Sales)
total_revenue = np.sum(df['Total Sales'].values)
print(f"6️ Total Revenue (Sum of Sales): {total_revenue:.2f}")

# 7. Coefficient of Variation for Units Sold (standard deviation / mean)
units_std = np.std(df['Units Sold'].values)
units_mean = np.mean(df['Units Sold'].values)
coef_variation_units = units_std / units_mean
print(f"7️ Coefficient of Variation (Units Sold): {coef_variation_units:.4f}")
# Out:
# 1️ Mean Price per Unit: 40.84
# 2️ Median Units Sold: 325.0
# 3️ Standard Deviation of Total Sales: 132574.59
# 4️ Maximum Operating Profit: 253750.00
# 5️ Minimum Operating Profit: 631.12
# 6️ Total Revenue (Sum of Sales): 33803828.00
# 7️ Coefficient of Variation (Units Sold): 0.6114

# %%
# Operation Using Scipy
from scipy.stats import kruskal
# Group data by Region
grouped_units = [group['Units Sold'].values for name, group in df.groupby('Region')]

# Performing Kruskal-Wallis H-test
h_stat, p_val = kruskal(*grouped_units)

print("= Kruskal-Wallis Test on Units Sold by Region =")
print(f"H-statistic: {h_stat:.4f}")
print(f"P-value: {p_val:.4f}")

# Interpretation
if p_val < 0.05:
    print(" Statistically significant difference in Units Sold between regions.")
else:
    print(" No statistically significant difference in Units Sold between regions.")
# Out:
# = Kruskal-Wallis Test on Units Sold by Region =
# H-statistic: 79.9376
# P-value: 0.0000
#  Statistically significant difference in Units Sold between regions.

# %%
# Operation Using Statsmodel
import pandas as pd
import statsmodels.api as sm

# Cleaning the data by dropping any rows with missing values (Just in case)
df_cleaned = df.dropna()

# Defining independent variable
X = df_cleaned[['Price per Unit', 'Units Sold']] 

# Defining dependent variable
y = df_cleaned['Operating Profit'] 

# Adding constant for intercept
X = sm.add_constant(X)

# OLS regression
model = sm.OLS(y, X).fit()

# Display regression summary
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       Operating Profit   R-squared:                       0.867
# Model:                            OLS   Adj. R-squared:                  0.866
# Method:                 Least Squares   F-statistic:                     817.4
# Date:                Sun, 18 May 2025   Prob (F-statistic):          2.15e-110
# Time:                        22:18:37   Log-Likelihood:                -2875.6
# No. Observations:                 253   AIC:                             5757.
# Df Residuals:                     250   BIC:                             5768.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const           -7.69e+04   4224.481    -18.205      0.000   -8.52e+04   -6.86e+04
# Price per Unit  1345.3255     92.463     14.550      0.000    1163.220    1527.431
# Units Sold       213.4082      6.187     34.495      0.000     201.224     225.593
# ==============================================================================
# Omnibus:                       32.508   Durbin-Watson:                   1.605
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               64.563
# Skew:                           0.664   Prob(JB):                     9.56e-15
# Kurtosis:                       5.088   Cond. No.                     1.34e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.34e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# Visualizations of the data
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the data (assuming it's already clean)
df = pd.read_excel(r"C:\Users\joerl\Downloads\excel.xlsx", sheet_name="Sheet1")

# Set Seaborn style
sns.set(style="whitegrid")

# = 1. Histogram of "Units Sold" =
plt.figure(figsize=(8, 5))
sns.histplot(df['Units Sold'], bins=20, kde=True, color='steelblue')
plt.title("Distribution of Units Sold")
plt.xlabel("Units Sold")
plt.ylabel("Frequency")
plt.tight_layout()
plt.show()

# = 2. Bar Plot: Average Price per Unit by Product Category =
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
avg_price = df.groupby('Product Category')['Price per Unit'].mean().reset_index()

sns.barplot(data=avg_price, x='Product Category', y='Price per Unit')
plt.title("Average Price per Unit by Product Category")
plt.xlabel("Product Category")
plt.ylabel("Average Price")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

#3 Group by Region and sum Units Sold
units_per_region = df.groupby('Region')['Units Sold'].sum()

# Plot pie chart
plt.figure(figsize=(8, 8))
plt.pie(units_per_region, labels=units_per_region.index, autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired.colors)
plt.title("Units Sold by Region (Proportional)")
plt.axis('equal')  # Equal aspect ratio ensures the pie is circular.
plt.tight_layout()
plt.show()

# %%
# Correlation Plot with Regression Line
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats

# Scatter plot with regression line between Price per Unit and Units Sold
sns.lmplot(data=df, x='Price per Unit', y='Units Sold', height=6, aspect=1.5, line_kws={'color': 'red'})
plt.title("Correlation: Price per Unit vs. Units Sold")
plt.xlabel("Price per Unit")
plt.ylabel("Units Sold")
plt.tight_layout()
plt.show()

# Optional: Pearson correlation coefficient
r, p = stats.pearsonr(df['Price per Unit'], df['Units Sold'])
print(f"Pearson correlation: r = {r:.2f}, p-value = {p:.4f}")
# Out:
# Pearson correlation: r = 0.18, p-value = 0.0041
